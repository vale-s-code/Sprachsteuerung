# %% [markdown]
# # Hello World
# Fast jedes Programmier-Tutorial beginnt mit einem "Hello World"-Programm.
# Wenn du diesen Text lesen kannst, war die Installation von Jupyter Notebook erfolgreich.
# Solche Textfelder erklären die folgenden Codeabschnitte.
#
# Unter diesem Textfeld siehst du ein Codebeispiel.
# Um es auszuführen, klicke auf den Pfeil links neben dem Codefeld.

# %%
print('Hello world')
# Out:
# Hello world

# %% [markdown]
# Nach der Ausführung wird die Ausgabe unterhalb des Feldes angezeigt.
# In diesem Fall wird nur "Hello world" ausgegeben.
#
# Herzlichen Glückwunsch, du hast dein erstes Python-Programm in einem Jupyter Notebook ausgeführt.

# %% [markdown]
# Für eine einzelne Kommentarzeile beginnt man mit einem #.
#
# Für mehrere Kommentarzeilen wird der Block mit ''' begonnen und beendet.

# %%
# This program is a simple HelloWorld example.
# These comments can be used, to explain the code.

'''
If you want to use several lines of code, you can beginn and end them by three quotation marks.
Now several lines can be used as comments.
'''
print('This is an introduction to comments.')
# comments can be inserted everywhere.
print('Comments are not executed during runtime.')
# Out:
# This is an introduction to comments.
# Comments are not executed during runtime.

# %% [markdown]
# ## Programmieraufgabe:
# Schreibe ein Programm, das die finale Antwort 42 ausgibt.
# Füge einen Kommentarblock hinzu, in dem festgehalten wird, in welchem Buch die finale Antwort auf 42 gesetzt wird.
